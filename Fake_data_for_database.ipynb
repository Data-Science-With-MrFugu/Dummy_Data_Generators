# %% [markdown]
# # Parsing Fake Addresses Using Python : [Pros & Cons]
#
# with **Mr Fugu Data Science**
#
# `___________________________________________________________________________________________`

# %% [markdown]
# If you have never used [faker] before: you are able to create fake data for testing; such as database applications
#
# **visit**: [faker_website](https://faker.readthedocs.io/en/master/)
#
# We will be parsing fake addresses with [usaddress]
#
# **visit**: [US address parser](https://usaddress.readthedocs.io/en/latest/)
#
# U.S. & World-Wide Addresses website: [real addresses](http://results.openaddresses.io/)
# these files are downloadable and used in first example

# %%
# !pip install faker
# !pip install usaddress

# %%
import os # search directory[s] for files 
import pandas as pd 
import usaddress # used to parse: US addresses
from faker import Factory,Faker # create fake: addresses
import csv # create/export csv_files 

fake_data=Faker()
fake_data.seed(4321) # setting a seed to ensure same results each time

# %% [markdown]
# # Using `OS` to locate files in various directories:
# + `This will assist in two ways:`
#     + using `OS` to find files outside of your working directory
#     + avoid hardcoding

# %% [markdown]
# # Current directory locating files:

# %%
# Find files in working directory:

def os_local_dir_search(file):
    d = os.getcwd()
    usr_dir = [os.path.join(d,o) for o in os.listdir(d) if os.path.isdir(os.path.join(d,o))]

    for item in usr_dir:
        if os.path.exists(item + file):
            file = item + file
    return file

# %% [markdown]
# # Walking from your directory to search for files:
# + this could be extended to outside of directory to system wide

# %%
# Find a file outside your directory:

def os_any_dir_search(file):
    u=[]
    for p,n,f in os.walk(os.getcwd()):
        
        for a in f:
            a = str(a)
            if a.endswith(file): # can be (.csv) or a file like I did and search 
                print(a)
                print(p)
                t=pd.read_csv(p+'/'+file)
    return t

# need to use (.csv,.png, etc) because it is looking by file type ending
os_any_dir_search('berkeley.csv').head()
# Out:
# berkeley.csv
# /Users/zatoichi59/Desktop/Projects/openaddr-collected-us_west/us/ca
#           LON        LAT  NUMBER      STREET UNIT      CITY  DISTRICT  REGION  \
# 0 -122.260714  37.863205    2550     DANA ST  NaN  BERKELEY       NaN     NaN
# 1 -122.289434  37.855691    1012  GRAYSON ST    A  BERKELEY       NaN     NaN
# 2 -122.289434  37.855691    1012  GRAYSON ST    C  BERKELEY       NaN     NaN
# 3 -122.294703  37.870741    1813    NINTH ST  NaN  BERKELEY       NaN     NaN
# 4 -122.289390  37.870799    1901   CURTIS ST  NaN  BERKELEY       NaN     NaN
#
#    POSTCODE             ID              HASH
# 0     94704  055 183213100  29adde543ce77829
# 1     94710  053 166004000  c177338841c6ef79
# 2     94710  053 166004200  8bc0fbe83c6df548
# 3     94710  057 209002100  8faa530f19246223
# 4     94702  057 208303100  5c07b797bead947f

# %%
# for p,n,f in os.walk(os.getcwd()):
#     print(p) # all directory ext
#     print(n) # find all files readable in directory
#     print(f) # list of everything in directory as a list-lists

# %% [markdown]
# # Ideal Situation: Real Addresses to parse: parsed two different ways
# + 1<sup>st</sup>: Using `usaddress.tag()`
# + 2<sup>nd</sup>: Using `usaddress.parse()`

# %%
berkeley_addr=os_any_dir_search('berkeley.csv')

berkeley_sub=berkeley_addr.loc[:,['NUMBER','STREET','UNIT','CITY','POSTCODE']].fillna(value='0').astype('str', copy=False)

berkeley_sub_lst=berkeley_sub.values.tolist()
# Out:
# berkeley.csv
# /Users/zatoichi59/Desktop/Projects/openaddr-collected-us_west/us/ca

# %% [markdown]
# # Convert Real Addresses with [usaddress.tag()]
# + This uses OrdDict() formatting

# %%
'''
def Convert(): coverting list of tuples to dictionary with (key,[value])

def list_to_liststr(): this is converting a list of list to list of strings used in parsing for usaddress

parse_tag: creates list of OrdDict() which is then converted into list of tuples used in the Covert() fcn

pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in dict_addr.items()])): 

this is used to iterated dictionary and create dataframe from dictionary with values that may be Nan
'''

dictionary = {} 
def Convert(tup, di): 
    for a, b in tup: 
        di.setdefault(a, []).append(b) 
    return di 

#--------------------------------

def list_to_liststr(nest_list):
    u=[]
    for i in nest_list:
        u.append(' '.join(i))
    hh=[]
    for i in u:
        hh.append(i) #using this to get rid of nested lists because parser can't read directly      
    return hh

#-----------------------------   

def parse_tag(address_stuff):
    h=[]
    for i in address_stuff:
        h.append(usaddress.tag(i)) 
    pp=[]
    for i in range(len(h)):
        o=h[i]
    #     pp.append([o[0].items()])
    #     op.append(o[0].values())
        for k in o[0].items():
                pp.append(k)             
    return pp
#--------------------------------

berk_=list_to_liststr(berkeley_sub_lst)

dict_addr=Convert(parse_tag(berk_),dictionary)

pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in dict_addr.items()])).head()
# Out:
#   AddressNumber StreetName StreetNamePostType OccupancyIdentifier ZipCode  \
# 0          2550       DANA                 ST          0 BERKELEY   94704
# 1          1012    GRAYSON                 ST          0 BERKELEY   94710
# 2          1012    GRAYSON                 ST          0 BERKELEY   94710
# 3          1813      NINTH                 ST          0 BERKELEY   94710
# 4          1901     CURTIS                 ST          1 BERKELEY   94702
#
#   PlaceName StateName StreetNamePostDirectional               BuildingName  \
# 0         A  BERKELEY                         E  60 THE UPLANDS 0 BERKELEY
# 1         C  BERKELEY                         N  50 THE UPLANDS 0 BERKELEY
# 2         A  BERKELEY                         E  70 THE UPLANDS 0 BERKELEY
# 3         B  BERKELEY                         E  90 THE UPLANDS 0 BERKELEY
# 4        ST  BERKELEY                         E  30 THE UPLANDS 0 BERKELEY
#
#   StreetNamePreModifier StreetNamePreType
# 0                    EL            CAMINO
# 1                    EL            CAMINO
# 2                    EL            CAMINO
# 3                    EL            CAMINO
# 4                    EL            CAMINO

# %%
h=[]
for i in berk_:
    h.append(usaddress.tag(i)) 
    pp=[]
for i in range(len(h)):
    o=h[i]
    #     pp.append([o[0].items()])
    #     op.append(o[0].values())
    for k in o[0].items():
        pp.append(k)
pp
# Out:
# [('AddressNumber', '2550'),
#  ('StreetName', 'DANA'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1012'),
#  ('StreetName', 'GRAYSON'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1012'),
#  ('StreetName', 'GRAYSON'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'C'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1813'),
#  ('StreetName', 'NINTH'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1901'),
#  ('StreetName', 'CURTIS'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1829'),
#  ('StreetName', 'SIXTY-THIRD'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2641'),
#  ('StreetName', 'WEBSTER'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1314'),
#  ('StreetName', 'HASKELL'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2522'),
#  ('StreetName', 'DANA'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '101'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2122'),
#  ('StreetName', 'JEFFERSON'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1917'),
#  ('StreetName', 'FRANCISCO'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1646'),
#  ('StreetName', 'CORNELL'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1645'),
#  ('StreetName', 'CORNELL'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1709'),
#  ('StreetName', 'MILVIA'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2301'),
#  ('StreetName', 'VIRGINIA'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1176'),
#  ('StreetName', 'ARCH'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94708'),
#  ('AddressNumber', '1178'),
#  ('StreetName', 'EUCLID'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94708'),
#  ('AddressNumber', '2515'),
#  ('StreetName', 'ASHBY'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '2 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2928'),
#  ('StreetName', 'FLORENCE'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'B'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2914'),
#  ('StreetName', 'DEAKIN'),
#  ('PlaceName', 'ST'),
#  ('StateName', 'A2 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '928'),
#  ('StreetName', 'CARLETON'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2723'),
#  ('StreetName', 'ASHBY'),
#  ('StreetNamePostType', 'PL'),
#  ('PlaceName', 'B'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1412'),
#  ('StreetName', 'OXFORD'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2006'),
#  ('StreetName', 'ROSE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2234'),
#  ('StreetName', 'WARD'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1812'),
#  ('StreetName', 'PARKER'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1411'),
#  ('StreetName', 'SPRUCE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '933'),
#  ('StreetName', 'ADDISON'),
#  ('StreetNamePostType', 'ST'),
#  ('StreetNamePostDirectional', 'E'),
#  ('PlaceName', 'BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2228'),
#  ('StreetName', 'SIXTH'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1128'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1140'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2611'),
#  ('StreetName', 'PIEDMONT'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2403'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1214'),
#  ('StreetName', 'ASHBY'),
#  ('StreetNamePostType', 'AVE'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2842'),
#  ('StreetName', 'WOOLSEY'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2820'),
#  ('StreetName', 'PRINCE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2725'),
#  ('StreetName', 'PRINCE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1721'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1926'),
#  ('StreetName', 'FRANCISCO'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1401'),
#  ('StreetName', 'ACTON'),
#  ('StreetNamePostType', 'CRES'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2900'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2141'),
#  ('StreetName', 'OREGON'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2315'),
#  ('StreetName', 'EDWARDS'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2406'),
#  ('StreetName', 'DANA'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1846'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2326'),
#  ('StreetName', 'LE CONTE'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1020'),
#  ('StreetName', 'JONES'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1642'),
#  ('StreetName', 'MILVIA'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2216'),
#  ('StreetName', 'LOS ANGELES'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94707'),
#  ('AddressNumber', '2792'),
#  ('StreetName', 'SHASTA'),
#  ('StreetNamePostType', 'RD'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94708'),
#  ('AddressNumber', '2987'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '51'),
#  ('StreetName', 'OAKVALE'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2927'),
#  ('StreetName', 'BENVENUE'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2906'),
#  ('StreetName', 'BENVENUE'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1711'),
#  ('StreetName', 'NINTH'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1417'),
#  ('StreetName', 'OXFORD'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1241'),
#  ('StreetName', 'EVELYN'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94706'),
#  ('AddressNumber', '1732'),
#  ('StreetName', 'HEARST'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2330'),
#  ('StreetName', 'TENTH'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2316'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2611'),
#  ('StreetName', 'LE CONTE'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1328'),
#  ('StreetName', 'ADA'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1320'),
#  ('StreetName', 'NINTH'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1578'),
#  ('StreetName', 'HOPKINS'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94707'),
#  ('AddressNumber', '1124'),
#  ('StreetName', 'OXFORD'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94707'),
#  ('AddressNumber', '910'),
#  ('StreetName', 'COLUSA'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '2 BERKELEY'),
#  ('ZipCode', '94707'),
#  ('AddressNumber', '2106'),
#  ('StreetName', 'CALIFORNIA'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1545'),
#  ('StreetName', 'ADDISON'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1309'),
#  ('StreetName', 'HOPKINS'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1231'),
#  ('StreetName', 'FOURTH'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1230'),
#  ('StreetName', 'KAINS'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94706'),
#  ('AddressNumber', '1846'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '3 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2804'),
#  ('StreetName', 'HILLEGASS'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '3 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2314'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2741'),
#  ('StreetName', 'GARBER'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '2 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2444'),
#  ('StreetName', 'VIRGINIA'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'B'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2210'),
#  ('StreetName', 'STUART'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2808'),
#  ('StreetName', 'HILLEGASS'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', 'A1'),
#  ('PlaceName', 'BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2623'),
#  ('StreetName', 'BENVENUE'),
#  ('StreetNamePostType', 'AVE'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1921'),
#  ('StreetName', 'HASTE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1521'),
#  ('StreetName', 'HEARST'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1207'),
#  ('StreetName', 'FRANCISCO'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1232'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1718'),
#  ('StreetName', 'CHANNING'),
#  ('StreetNamePostType', 'WAY'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2365'),
#  ('StreetName', 'VIRGINIA'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '800'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1-1'),
#  ('PlaceName', 'BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2601'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '107'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2120'),
#  ('StreetName', 'SIXTH'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '7 BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2985'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '51'),
#  ('StreetName', 'OAKVALE'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2922'),
#  ('StreetName', 'HILLEGASS'),
#  ('StreetNamePostType', 'AVE'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2980'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1434'),
#  ('StreetName', 'BERKELEY'),
#  ('StreetNamePostType', 'WAY'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1336'),
#  ('StreetName', 'BERKELEY'),
#  ('StreetNamePostType', 'WAY'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1209'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2550'),
#  ('StreetName', 'DANA'),
#  ('PlaceName', 'ST'),
#  ('StateName', 'G1 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2430'),
#  ('StreetName', 'FIFTH'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1814'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2326'),
#  ('StreetName', 'BROWNING'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1515'),
#  ('StreetName', 'HOPKINS'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '5 BERKELEY'),
#  ('ZipCode', '94707'),
#  ('AddressNumber', '1404'),
#  ('StreetName', 'HENRY'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '2 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2634'),
#  ('StreetName', 'VIRGINIA'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '23'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2325'),
#  ('StreetName', 'HOWE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2316'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'B'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2602'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2405'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2600'),
#  ('StreetName', 'ETNA'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '3 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2430'),
#  ('StreetName', 'TENTH'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '3036'),
#  ('StreetName', 'FULTON'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2636'),
#  ('StreetName', 'REGENT'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '3109'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '3045'),
#  ('StreetName', 'DEAKIN'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'L'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1832'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1629'),
#  ('StreetName', 'EIGHTH'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2021'),
#  ('StreetName', 'HEARST'),
#  ('StreetNamePostType', 'AVE'),
#  ('PlaceName', 'B'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2220'),
#  ('StreetName', 'SACRAMENTO'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '7 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1810'),
#  ('StreetName', 'DWIGHT'),
#  ('StreetNamePostType', 'WAY'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2980'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '9 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2550'),
#  ('StreetName', 'DANA'),
#  ('PlaceName', 'ST'),
#  ('StateName', 'G9 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '930'),
#  ('StreetName', 'CARLETON'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2723'),
#  ('StreetName', 'ASHBY'),
#  ('StreetNamePostType', 'PL'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1726'),
#  ('StreetName', 'HEARST'),
#  ('StreetNamePostType', 'AVE'),
#  ('PlaceName', 'B'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2314'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2547'),
#  ('StreetName', 'PIEDMONT'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '2 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1294'),
#  ('StreetName', 'MONTEREY'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94707'),
#  ('AddressNumber', '2043'),
#  ('StreetName', 'BERRYMAN'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2418'),
#  ('StreetName', 'FIFTH'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'B'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2601'),
#  ('StreetName', 'DANA'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2632'),
#  ('StreetName', 'HILLEGASS'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1740'),
#  ('StreetName', 'ADDISON'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1812'),
#  ('StreetName', 'SIXTH'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1672'),
#  ('StreetName', 'UNIVERSITY'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2550'),
#  ('StreetName', 'DANA'),
#  ('PlaceName', 'ST'),
#  ('StateName', 'G6 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2348'),
#  ('StreetName', 'HILGARD'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2741'),
#  ('StreetName', 'GARBER'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '6 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2016'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'C'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2414'),
#  ('StreetName', 'HILGARD'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2634'),
#  ('StreetName', 'VIRGINIA'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '12'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1658'),
#  ('StreetName', 'CALIFORNIA'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1785'),
#  ('StreetName', 'OXFORD'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1767'),
#  ('StreetName', 'EUCLID'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1521'),
#  ('StreetName', 'M L KING JR'),
#  ('StreetNamePostType', 'WAY'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2501'),
#  ('StreetName', 'DANA'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2425'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2646'),
#  ('StreetName', 'ASHBY'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2323'),
#  ('StreetName', 'HOWE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '2 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1822'),
#  ('StreetName', 'BERKELEY'),
#  ('StreetNamePostType', 'WAY'),
#  ('OccupancyIdentifier', '2 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1211'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2512'),
#  ('StreetName', 'NINTH'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2415'),
#  ('StreetName', 'FIFTH'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2115'),
#  ('StreetName', 'STUART'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2133'),
#  ('StreetName', 'DERBY'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2640'),
#  ('StreetName', 'BENVENUE'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2626'),
#  ('StreetName', 'BENVENUE'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2905'),
#  ('StreetName', 'CHANNING'),
#  ('StreetNamePostType', 'WAY'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1300'),
#  ('StreetName', 'ADDISON'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2029'),
#  ('StreetName', 'CHANNING'),
#  ('StreetNamePostType', 'WAY'),
#  ('OccupancyIdentifier', '2B'),
#  ('PlaceName', 'BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2220'),
#  ('StreetName', 'SACRAMENTO'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '6 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2201'),
#  ('StreetName', 'VIRGINIA'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '6 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1730'),
#  ('StreetName', 'HIGHLAND'),
#  ('StreetNamePostType', 'PL'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2614'),
#  ('StreetName', 'WARRING'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '3 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2407'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1012'),
#  ('StreetName', 'GRAYSON'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'B'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1127'),
#  ('StreetName', 'HEARST'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1729'),
#  ('StreetName', 'SIXTH'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2619'),
#  ('StreetName', 'ETNA'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1336'),
#  ('StreetName', 'SEVENTH'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1417'),
#  ('StreetName', 'SPRUCE'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1410'),
#  ('StreetName', 'HENRY'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2832'),
#  ('StreetName', 'WEBSTER'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2815'),
#  ('StreetName', 'PIEDMONT'),
#  ('StreetNamePostType', 'AVE'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2904'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1300'),
#  ('StreetName', 'SHATTUCK'),
#  ('StreetNamePostType', 'AVE'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1219'),
#  ('StreetName', 'OXFORD'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '933'),
#  ('StreetName', 'ADDISON'),
#  ('StreetNamePostType', 'ST'),
#  ('PlaceName', 'B'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1414'),
#  ('StreetName', 'OXFORD'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1411'),
#  ('StreetName', 'WALNUT'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2484'),
#  ('StreetName', 'M L KING JR'),
#  ('StreetNamePostType', 'WAY'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2486'),
#  ('StreetName', 'M L KING JR'),
#  ('StreetNamePostType', 'WAY'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2149'),
#  ('StreetName', 'STUART'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1801'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2311'),
#  ('StreetName', 'JEFFERSON'),
#  ('StreetNamePostType', 'AVE'),
#  ('PlaceName', 'A'),
#  ('StateName', 'BERKELEY'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1653'),
#  ('StreetName', 'SCENIC'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1635'),
#  ('StreetName', 'SCENIC'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2566'),
#  ('StreetName', 'VIRGINIA'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1406'),
#  ('StreetName', 'EUCLID'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '1 BERKELEY'),
#  ('ZipCode', '94708'),
#  ('AddressNumber', '1414'),
#  ('StreetName', 'SPRING'),
#  ('StreetNamePostType', 'WAY'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94708'),
#  ('AddressNumber', '3017'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE'),
#  ('OccupancyIdentifier', '2 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2141'),
#  ('StreetName', 'OREGON'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '2 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2815'),
#  ('StreetName', 'REGENT'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '2 BERKELEY'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1235'),
#  ('StreetName', 'HENRY'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1237'),
#  ('StreetName', 'OXFORD'),
#  ('StreetNamePostType', 'ST'),
#  ('OccupancyIdentifier', '0 BERKELEY'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1219'),
#  ...]

# %% [markdown]
# # Real Address parsing with [usaddress.parse()]:
# + This is `NOT using OrdDict() formatting`

# %%
#------------- Need to iterate nested list and create list of strings for parsing ------------
def parse_w_parse(real_addr_lst):
    parse_lst=[]
    for i in real_addr_lst:
        parse_lst.append(','.join(i))
    wow=[]
    for h in parse_lst:
        wow.extend(usaddress.parse(h))
    tq=[(sub[1], sub[0]) for sub in wow]
    return tq

#--------------------------------
tq=parse_w_parse(berkeley_sub_lst)
oui=Convert(tq,dictionary)
pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in oui.items()])).head()
# Out:
#   AddressNumber StreetName StreetNamePostType OccupancyIdentifier ZipCode  \
# 0          2550       DANA                 ST          0 BERKELEY   94704
# 1          1012    GRAYSON                 ST          0 BERKELEY   94710
# 2          1012    GRAYSON                 ST          0 BERKELEY   94710
# 3          1813      NINTH                 ST          0 BERKELEY   94710
# 4          1901     CURTIS                 ST          1 BERKELEY   94702
#
#   PlaceName StateName StreetNamePostDirectional               BuildingName  \
# 0         A  BERKELEY                         E  60 THE UPLANDS 0 BERKELEY
# 1         C  BERKELEY                         N  50 THE UPLANDS 0 BERKELEY
# 2         A  BERKELEY                         E  70 THE UPLANDS 0 BERKELEY
# 3         B  BERKELEY                         E  90 THE UPLANDS 0 BERKELEY
# 4        ST  BERKELEY                         E  30 THE UPLANDS 0 BERKELEY
#
#   StreetNamePreModifier StreetNamePreType OccupancyType  \
# 0                    EL            CAMINO     BERKELEY,
# 1                    EL            CAMINO     BERKELEY,
# 2                    EL            CAMINO     BERKELEY,
# 3                    EL            CAMINO     BERKELEY,
# 4                    EL            CAMINO     BERKELEY,
#
#   StreetNamePreDirectional
# 0                     WEST
# 1                     WEST
# 2                     WEST
# 3                     WEST
# 4                     WEST

# %%
parse_lst=[]
for i in berkeley_sub_lst:
    parse_lst.append(','.join(i))
wow=[]
for h in parse_lst:
    wow.extend(usaddress.parse(h))
tq=[(sub[1], sub[0]) for sub in wow]

# %%
parse_lst
# Out:
# ['2550,DANA ST,0,BERKELEY,94704',
#  '1012,GRAYSON ST,A,BERKELEY,94710',
#  '1012,GRAYSON ST,C,BERKELEY,94710',
#  '1813,NINTH ST,0,BERKELEY,94710',
#  '1901,CURTIS ST,0,BERKELEY,94702',
#  '1829,SIXTY-THIRD ST,0,BERKELEY,94703',
#  '2641,WEBSTER ST,1,BERKELEY,94705',
#  '1314,HASKELL ST,A,BERKELEY,94702',
#  '2522,DANA ST,101,BERKELEY,94704',
#  '2122,JEFFERSON AVE,0,BERKELEY,94703',
#  '1917,FRANCISCO ST,0,BERKELEY,94709',
#  '1646,CORNELL AVE,0,BERKELEY,94702',
#  '1645,CORNELL AVE,0,BERKELEY,94702',
#  '1709,MILVIA ST,0,BERKELEY,94709',
#  '2301,VIRGINIA ST,1,BERKELEY,94709',
#  '1176,ARCH ST,0,BERKELEY,94708',
#  '1178,EUCLID AVE,1,BERKELEY,94708',
#  '2515,ASHBY AVE,2,BERKELEY,94705',
#  '2928,FLORENCE ST,B,BERKELEY,94705',
#  '2914,DEAKIN ST,A2,BERKELEY,94705',
#  '928,CARLETON ST,0,BERKELEY,94710',
#  '2723,ASHBY PL,B,BERKELEY,94705',
#  '1412,OXFORD ST,0,BERKELEY,94709',
#  '2006,ROSE ST,0,BERKELEY,94709',
#  '2234,WARD ST,1,BERKELEY,94705',
#  '1812,PARKER ST,0,BERKELEY,94703',
#  '1411,SPRUCE ST,1,BERKELEY,94709',
#  '933,ADDISON ST,E,BERKELEY,94710',
#  '2228,SIXTH ST,0,BERKELEY,94710',
#  '1128,DELAWARE ST,0,BERKELEY,94702',
#  '1140,DELAWARE ST,1,BERKELEY,94702',
#  '2611,PIEDMONT AVE,1,BERKELEY,94704',
#  '2403,BLAKE ST,0,BERKELEY,94704',
#  '1214,ASHBY AVE,A,BERKELEY,94702',
#  '2842,WOOLSEY ST,1,BERKELEY,94705',
#  '2820,PRINCE ST,0,BERKELEY,94705',
#  '2725,PRINCE ST,1,BERKELEY,94705',
#  '1721,DELAWARE ST,0,BERKELEY,94703',
#  '1926,FRANCISCO ST,0,BERKELEY,94709',
#  '1401,ACTON CRES,0,BERKELEY,94702',
#  '2900,COLLEGE AVE,0,BERKELEY,94705',
#  '2141,OREGON ST,1,BERKELEY,94705',
#  '2315,EDWARDS ST,0,BERKELEY,94702',
#  '2406,DANA ST,A,BERKELEY,94704',
#  '1846,DELAWARE ST,1,BERKELEY,94703',
#  '2326,LE CONTE AVE,1,BERKELEY,94709',
#  '1020,JONES ST,0,BERKELEY,94710',
#  '1642,MILVIA ST,1,BERKELEY,94709',
#  '2216,LOS ANGELES AVE,0,BERKELEY,94707',
#  '2792,SHASTA RD,0,BERKELEY,94708',
#  '2987,COLLEGE AVE,0,BERKELEY,94705',
#  '51,OAKVALE AVE,0,BERKELEY,94705',
#  '2927,BENVENUE AVE,0,BERKELEY,94705',
#  '2112,MCKINLEY AVE,D,BERKELEY,94703',
#  '1450,FOURTH ST,5,BERKELEY,94710',
#  '2,PANORAMIC WAY,304,BERKELEY,94704',
#  '2700,LE CONTE AVE,405,BERKELEY,94709',
#  '1411,SPRUCE ST,4,BERKELEY,94709',
#  '1584,HOPKINS ST,0,BERKELEY,94707',
#  '2515,ASHBY AVE,4,BERKELEY,94705',
#  '1178,EUCLID AVE,3,BERKELEY,94708',
#  '1326,SHATTUCK AVE,3,BERKELEY,94709',
#  '2648,ASHBY AVE,0,BERKELEY,94705',
#  '2576,VIRGINIA ST,7,BERKELEY,94709',
#  '2745,TENTH ST,0,BERKELEY,94710',
#  '2328,LE CONTE AVE,0,BERKELEY,94709',
#  '1502,TENTH ST,0,BERKELEY,94710',
#  '2303,GRANT ST,0,BERKELEY,94703',
#  ...]

# %%
wow
# Out:
# [('2550,', 'AddressNumber'),
#  ('DANA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('1012,', 'AddressNumber'),
#  ('GRAYSON', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('A,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94710', 'ZipCode'),
#  ('1012,', 'AddressNumber'),
#  ('GRAYSON', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('C,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94710', 'ZipCode'),
#  ('1813,', 'AddressNumber'),
#  ('NINTH', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94710', 'ZipCode'),
#  ('1901,', 'AddressNumber'),
#  ('CURTIS', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('1829,', 'AddressNumber'),
#  ('SIXTY-THIRD', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94703', 'ZipCode'),
#  ('2641,', 'AddressNumber'),
#  ('WEBSTER', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('1314,', 'AddressNumber'),
#  ('HASKELL', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('A,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94702', 'ZipCode'),
#  ('2522,', 'AddressNumber'),
#  ('DANA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('101,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'StateName'),
#  ('94704', 'ZipCode'),
#  ('2122,', 'AddressNumber'),
#  ('JEFFERSON', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94703', 'ZipCode'),
#  ('1917,', 'AddressNumber'),
#  ('FRANCISCO', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('1646,', 'AddressNumber'),
#  ('CORNELL', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('1645,', 'AddressNumber'),
#  ('CORNELL', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('1709,', 'AddressNumber'),
#  ('MILVIA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('2301,', 'AddressNumber'),
#  ('VIRGINIA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('1176,', 'AddressNumber'),
#  ('ARCH', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94708', 'ZipCode'),
#  ('1178,', 'AddressNumber'),
#  ('EUCLID', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94708', 'ZipCode'),
#  ('2515,', 'AddressNumber'),
#  ('ASHBY', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('2,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('2928,', 'AddressNumber'),
#  ('FLORENCE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('B,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94705', 'ZipCode'),
#  ('2914,', 'AddressNumber'),
#  ('DEAKIN', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('A2,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'PlaceName'),
#  ('94705', 'ZipCode'),
#  ('928,', 'AddressNumber'),
#  ('CARLETON', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94710', 'ZipCode'),
#  ('2723,', 'AddressNumber'),
#  ('ASHBY', 'StreetName'),
#  ('PL,', 'StreetNamePostType'),
#  ('B,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94705', 'ZipCode'),
#  ('1412,', 'AddressNumber'),
#  ('OXFORD', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('2006,', 'AddressNumber'),
#  ('ROSE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('2234,', 'AddressNumber'),
#  ('WARD', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('1812,', 'AddressNumber'),
#  ('PARKER', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94703', 'ZipCode'),
#  ('1411,', 'AddressNumber'),
#  ('SPRUCE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('933,', 'AddressNumber'),
#  ('ADDISON', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('E,', 'StreetNamePostDirectional'),
#  ('BERKELEY,', 'PlaceName'),
#  ('94710', 'ZipCode'),
#  ('2228,', 'AddressNumber'),
#  ('SIXTH', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94710', 'ZipCode'),
#  ('1128,', 'AddressNumber'),
#  ('DELAWARE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('1140,', 'AddressNumber'),
#  ('DELAWARE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('2611,', 'AddressNumber'),
#  ('PIEDMONT', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('2403,', 'AddressNumber'),
#  ('BLAKE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('1214,', 'AddressNumber'),
#  ('ASHBY', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('A,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94702', 'ZipCode'),
#  ('2842,', 'AddressNumber'),
#  ('WOOLSEY', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('2820,', 'AddressNumber'),
#  ('PRINCE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('2725,', 'AddressNumber'),
#  ('PRINCE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('1721,', 'AddressNumber'),
#  ('DELAWARE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94703', 'ZipCode'),
#  ('1926,', 'AddressNumber'),
#  ('FRANCISCO', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('1401,', 'AddressNumber'),
#  ('ACTON', 'StreetName'),
#  ('CRES,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('2900,', 'AddressNumber'),
#  ('COLLEGE', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('2141,', 'AddressNumber'),
#  ('OREGON', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('2315,', 'AddressNumber'),
#  ('EDWARDS', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('2406,', 'AddressNumber'),
#  ('DANA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('A,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94704', 'ZipCode'),
#  ('1846,', 'AddressNumber'),
#  ('DELAWARE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94703', 'ZipCode'),
#  ('2326,', 'AddressNumber'),
#  ('LE', 'StreetName'),
#  ('CONTE', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('1020,', 'AddressNumber'),
#  ('JONES', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94710', 'ZipCode'),
#  ('1642,', 'AddressNumber'),
#  ('MILVIA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('2216,', 'AddressNumber'),
#  ('LOS', 'StreetName'),
#  ('ANGELES', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94707', 'ZipCode'),
#  ('2792,', 'AddressNumber'),
#  ('SHASTA', 'StreetName'),
#  ('RD,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94708', 'ZipCode'),
#  ('2987,', 'AddressNumber'),
#  ('COLLEGE', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('51,', 'AddressNumber'),
#  ('OAKVALE', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('2927,', 'AddressNumber'),
#  ('BENVENUE', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('2906,', 'AddressNumber'),
#  ('BENVENUE', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('1711,', 'AddressNumber'),
#  ('NINTH', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94710', 'ZipCode'),
#  ('1417,', 'AddressNumber'),
#  ('OXFORD', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('1241,', 'AddressNumber'),
#  ('EVELYN', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94706', 'ZipCode'),
#  ('1732,', 'AddressNumber'),
#  ('HEARST', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94703', 'ZipCode'),
#  ('2330,', 'AddressNumber'),
#  ('TENTH', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94710', 'ZipCode'),
#  ('2316,', 'AddressNumber'),
#  ('BLAKE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('A,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94704', 'ZipCode'),
#  ('2611,', 'AddressNumber'),
#  ('LE', 'StreetName'),
#  ('CONTE', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('1328,', 'AddressNumber'),
#  ('ADA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('1320,', 'AddressNumber'),
#  ('NINTH', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94710', 'ZipCode'),
#  ('1578,', 'AddressNumber'),
#  ('HOPKINS', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94707', 'ZipCode'),
#  ('1124,', 'AddressNumber'),
#  ('OXFORD', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94707', 'ZipCode'),
#  ('910,', 'AddressNumber'),
#  ('COLUSA', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('2,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94707', 'ZipCode'),
#  ('2106,', 'AddressNumber'),
#  ('CALIFORNIA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94703', 'ZipCode'),
#  ('1545,', 'AddressNumber'),
#  ('ADDISON', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94703', 'ZipCode'),
#  ('1309,', 'AddressNumber'),
#  ('HOPKINS', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('1231,', 'AddressNumber'),
#  ('FOURTH', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('A,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94710', 'ZipCode'),
#  ('1230,', 'AddressNumber'),
#  ('KAINS', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94706', 'ZipCode'),
#  ('1846,', 'AddressNumber'),
#  ('DELAWARE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('3,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94703', 'ZipCode'),
#  ('2804,', 'AddressNumber'),
#  ('HILLEGASS', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('3,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('2314,', 'AddressNumber'),
#  ('BLAKE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('2741,', 'AddressNumber'),
#  ('GARBER', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('2,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('2444,', 'AddressNumber'),
#  ('VIRGINIA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('B,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94709', 'ZipCode'),
#  ('2210,', 'AddressNumber'),
#  ('STUART', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('2808,', 'AddressNumber'),
#  ('HILLEGASS', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('A1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'PlaceName'),
#  ('94705', 'ZipCode'),
#  ('2623,', 'AddressNumber'),
#  ('BENVENUE', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('A,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94704', 'ZipCode'),
#  ('1921,', 'AddressNumber'),
#  ('HASTE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('1521,', 'AddressNumber'),
#  ('HEARST', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94703', 'ZipCode'),
#  ('1207,', 'AddressNumber'),
#  ('FRANCISCO', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('1232,', 'AddressNumber'),
#  ('DELAWARE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('1718,', 'AddressNumber'),
#  ('CHANNING', 'StreetName'),
#  ('WAY,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94703', 'ZipCode'),
#  ('2365,', 'AddressNumber'),
#  ('VIRGINIA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('800,', 'AddressNumber'),
#  ('DELAWARE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1-1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'PlaceName'),
#  ('94710', 'ZipCode'),
#  ('2601,', 'AddressNumber'),
#  ('COLLEGE', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('107,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'StateName'),
#  ('94704', 'ZipCode'),
#  ('2120,', 'AddressNumber'),
#  ('SIXTH', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('7,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94710', 'ZipCode'),
#  ('2985,', 'AddressNumber'),
#  ('COLLEGE', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('51,', 'AddressNumber'),
#  ('OAKVALE', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('2922,', 'AddressNumber'),
#  ('HILLEGASS', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('A,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94705', 'ZipCode'),
#  ('2980,', 'AddressNumber'),
#  ('COLLEGE', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('1434,', 'AddressNumber'),
#  ('BERKELEY', 'StreetName'),
#  ('WAY,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('1336,', 'AddressNumber'),
#  ('BERKELEY', 'StreetName'),
#  ('WAY,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('1209,', 'AddressNumber'),
#  ('DELAWARE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('2550,', 'AddressNumber'),
#  ('DANA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('G1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'PlaceName'),
#  ('94704', 'ZipCode'),
#  ('2430,', 'AddressNumber'),
#  ('FIFTH', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('A,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94710', 'ZipCode'),
#  ('1814,', 'AddressNumber'),
#  ('BLAKE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94703', 'ZipCode'),
#  ('2326,', 'AddressNumber'),
#  ('BROWNING', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('1515,', 'AddressNumber'),
#  ('HOPKINS', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('5,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94707', 'ZipCode'),
#  ('1404,', 'AddressNumber'),
#  ('HENRY', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('2,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('2634,', 'AddressNumber'),
#  ('VIRGINIA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('23,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'StateName'),
#  ('94709', 'ZipCode'),
#  ('2325,', 'AddressNumber'),
#  ('HOWE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('2316,', 'AddressNumber'),
#  ('BLAKE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('B,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94704', 'ZipCode'),
#  ('2602,', 'AddressNumber'),
#  ('COLLEGE', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('2405,', 'AddressNumber'),
#  ('BLAKE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('2600,', 'AddressNumber'),
#  ('ETNA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('3,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('2430,', 'AddressNumber'),
#  ('TENTH', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94710', 'ZipCode'),
#  ('3036,', 'AddressNumber'),
#  ('FULTON', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('A,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94705', 'ZipCode'),
#  ('2636,', 'AddressNumber'),
#  ('REGENT', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('3109,', 'AddressNumber'),
#  ('COLLEGE', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('A,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94705', 'ZipCode'),
#  ('3045,', 'AddressNumber'),
#  ('DEAKIN', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('L,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94705', 'ZipCode'),
#  ('1832,', 'AddressNumber'),
#  ('DELAWARE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94703', 'ZipCode'),
#  ('1629,', 'AddressNumber'),
#  ('EIGHTH', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94710', 'ZipCode'),
#  ('2021,', 'AddressNumber'),
#  ('HEARST', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('B,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94709', 'ZipCode'),
#  ('2220,', 'AddressNumber'),
#  ('SACRAMENTO', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('7,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('1810,', 'AddressNumber'),
#  ('DWIGHT', 'StreetName'),
#  ('WAY,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94703', 'ZipCode'),
#  ('2980,', 'AddressNumber'),
#  ('COLLEGE', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('9,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('2550,', 'AddressNumber'),
#  ('DANA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('G9,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'PlaceName'),
#  ('94704', 'ZipCode'),
#  ('930,', 'AddressNumber'),
#  ('CARLETON', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94710', 'ZipCode'),
#  ('2723,', 'AddressNumber'),
#  ('ASHBY', 'StreetName'),
#  ('PL,', 'StreetNamePostType'),
#  ('A,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94705', 'ZipCode'),
#  ('1726,', 'AddressNumber'),
#  ('HEARST', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('B,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94703', 'ZipCode'),
#  ('2314,', 'AddressNumber'),
#  ('BLAKE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('2547,', 'AddressNumber'),
#  ('PIEDMONT', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('2,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('1294,', 'AddressNumber'),
#  ('MONTEREY', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94707', 'ZipCode'),
#  ('2043,', 'AddressNumber'),
#  ('BERRYMAN', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('2418,', 'AddressNumber'),
#  ('FIFTH', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('B,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94710', 'ZipCode'),
#  ('2601,', 'AddressNumber'),
#  ('DANA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('A,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94704', 'ZipCode'),
#  ('2632,', 'AddressNumber'),
#  ('HILLEGASS', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('1740,', 'AddressNumber'),
#  ('ADDISON', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('A,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94703', 'ZipCode'),
#  ('1812,', 'AddressNumber'),
#  ('SIXTH', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94710', 'ZipCode'),
#  ('1672,', 'AddressNumber'),
#  ('UNIVERSITY', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94703', 'ZipCode'),
#  ('2550,', 'AddressNumber'),
#  ('DANA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('G6,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'PlaceName'),
#  ('94704', 'ZipCode'),
#  ('2348,', 'AddressNumber'),
#  ('HILGARD', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('2741,', 'AddressNumber'),
#  ('GARBER', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('6,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('2016,', 'AddressNumber'),
#  ('DELAWARE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('C,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94709', 'ZipCode'),
#  ('2414,', 'AddressNumber'),
#  ('HILGARD', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('2634,', 'AddressNumber'),
#  ('VIRGINIA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('12,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'StateName'),
#  ('94709', 'ZipCode'),
#  ('1658,', 'AddressNumber'),
#  ('CALIFORNIA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94703', 'ZipCode'),
#  ('1785,', 'AddressNumber'),
#  ('OXFORD', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('1767,', 'AddressNumber'),
#  ('EUCLID', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('1521,', 'AddressNumber'),
#  ('M', 'StreetName'),
#  ('L', 'StreetName'),
#  ('KING', 'StreetName'),
#  ('JR', 'StreetName'),
#  ('WAY,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('2501,', 'AddressNumber'),
#  ('DANA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('2425,', 'AddressNumber'),
#  ('BLAKE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('2646,', 'AddressNumber'),
#  ('ASHBY', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('2323,', 'AddressNumber'),
#  ('HOWE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('2,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('1822,', 'AddressNumber'),
#  ('BERKELEY', 'StreetName'),
#  ('WAY,', 'StreetNamePostType'),
#  ('2,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94703', 'ZipCode'),
#  ('1211,', 'AddressNumber'),
#  ('DELAWARE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('2512,', 'AddressNumber'),
#  ('NINTH', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94710', 'ZipCode'),
#  ('2415,', 'AddressNumber'),
#  ('FIFTH', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94710', 'ZipCode'),
#  ('2115,', 'AddressNumber'),
#  ('STUART', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('2133,', 'AddressNumber'),
#  ('DERBY', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94705', 'ZipCode'),
#  ('2640,', 'AddressNumber'),
#  ('BENVENUE', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('2626,', 'AddressNumber'),
#  ('BENVENUE', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('2905,', 'AddressNumber'),
#  ('CHANNING', 'StreetName'),
#  ('WAY,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('1300,', 'AddressNumber'),
#  ('ADDISON', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('2029,', 'AddressNumber'),
#  ('CHANNING', 'StreetName'),
#  ('WAY,', 'StreetNamePostType'),
#  ('2B,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'PlaceName'),
#  ('94704', 'ZipCode'),
#  ('2220,', 'AddressNumber'),
#  ('SACRAMENTO', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('6,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('2201,', 'AddressNumber'),
#  ('VIRGINIA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('6,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('1730,', 'AddressNumber'),
#  ('HIGHLAND', 'StreetName'),
#  ('PL,', 'StreetNamePostType'),
#  ('1,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94709', 'ZipCode'),
#  ('2614,', 'AddressNumber'),
#  ('WARRING', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('3,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('2407,', 'AddressNumber'),
#  ('BLAKE', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94704', 'ZipCode'),
#  ('1012,', 'AddressNumber'),
#  ('GRAYSON', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('B,', 'PlaceName'),
#  ('BERKELEY,', 'StateName'),
#  ('94710', 'ZipCode'),
#  ('1127,', 'AddressNumber'),
#  ('HEARST', 'StreetName'),
#  ('AVE,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94702', 'ZipCode'),
#  ('1729,', 'AddressNumber'),
#  ('SIXTH', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('0,', 'OccupancyIdentifier'),
#  ('BERKELEY,', 'OccupancyIdentifier'),
#  ('94710', 'ZipCode'),
#  ('2619,', 'AddressNumber'),
#  ('ETNA', 'StreetName'),
#  ('ST,', 'StreetNamePostType'),
#  ('A,', 'PlaceName'),
#  ...]

# %%
tq
# Out:
# [('AddressNumber', '2550,'),
#  ('StreetName', 'DANA'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1012,'),
#  ('StreetName', 'GRAYSON'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'A,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1012,'),
#  ('StreetName', 'GRAYSON'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'C,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1813,'),
#  ('StreetName', 'NINTH'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1901,'),
#  ('StreetName', 'CURTIS'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1829,'),
#  ('StreetName', 'SIXTY-THIRD'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2641,'),
#  ('StreetName', 'WEBSTER'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1314,'),
#  ('StreetName', 'HASKELL'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'A,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2522,'),
#  ('StreetName', 'DANA'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '101,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2122,'),
#  ('StreetName', 'JEFFERSON'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1917,'),
#  ('StreetName', 'FRANCISCO'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1646,'),
#  ('StreetName', 'CORNELL'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1645,'),
#  ('StreetName', 'CORNELL'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1709,'),
#  ('StreetName', 'MILVIA'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2301,'),
#  ('StreetName', 'VIRGINIA'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1176,'),
#  ('StreetName', 'ARCH'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94708'),
#  ('AddressNumber', '1178,'),
#  ('StreetName', 'EUCLID'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94708'),
#  ('AddressNumber', '2515,'),
#  ('StreetName', 'ASHBY'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '2,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2928,'),
#  ('StreetName', 'FLORENCE'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'B,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2914,'),
#  ('StreetName', 'DEAKIN'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', 'A2,'),
#  ('PlaceName', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '928,'),
#  ('StreetName', 'CARLETON'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2723,'),
#  ('StreetName', 'ASHBY'),
#  ('StreetNamePostType', 'PL,'),
#  ('PlaceName', 'B,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1412,'),
#  ('StreetName', 'OXFORD'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2006,'),
#  ('StreetName', 'ROSE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2234,'),
#  ('StreetName', 'WARD'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1812,'),
#  ('StreetName', 'PARKER'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1411,'),
#  ('StreetName', 'SPRUCE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '933,'),
#  ('StreetName', 'ADDISON'),
#  ('StreetNamePostType', 'ST,'),
#  ('StreetNamePostDirectional', 'E,'),
#  ('PlaceName', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2228,'),
#  ('StreetName', 'SIXTH'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1128,'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1140,'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2611,'),
#  ('StreetName', 'PIEDMONT'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2403,'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1214,'),
#  ('StreetName', 'ASHBY'),
#  ('StreetNamePostType', 'AVE,'),
#  ('PlaceName', 'A,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2842,'),
#  ('StreetName', 'WOOLSEY'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2820,'),
#  ('StreetName', 'PRINCE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2725,'),
#  ('StreetName', 'PRINCE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1721,'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1926,'),
#  ('StreetName', 'FRANCISCO'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1401,'),
#  ('StreetName', 'ACTON'),
#  ('StreetNamePostType', 'CRES,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2900,'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2141,'),
#  ('StreetName', 'OREGON'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2315,'),
#  ('StreetName', 'EDWARDS'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2406,'),
#  ('StreetName', 'DANA'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'A,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1846,'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2326,'),
#  ('StreetName', 'LE'),
#  ('StreetName', 'CONTE'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1020,'),
#  ('StreetName', 'JONES'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1642,'),
#  ('StreetName', 'MILVIA'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2216,'),
#  ('StreetName', 'LOS'),
#  ('StreetName', 'ANGELES'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94707'),
#  ('AddressNumber', '2792,'),
#  ('StreetName', 'SHASTA'),
#  ('StreetNamePostType', 'RD,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94708'),
#  ('AddressNumber', '2987,'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '51,'),
#  ('StreetName', 'OAKVALE'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2927,'),
#  ('StreetName', 'BENVENUE'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2906,'),
#  ('StreetName', 'BENVENUE'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1711,'),
#  ('StreetName', 'NINTH'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1417,'),
#  ('StreetName', 'OXFORD'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1241,'),
#  ('StreetName', 'EVELYN'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94706'),
#  ('AddressNumber', '1732,'),
#  ('StreetName', 'HEARST'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2330,'),
#  ('StreetName', 'TENTH'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2316,'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'A,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2611,'),
#  ('StreetName', 'LE'),
#  ('StreetName', 'CONTE'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1328,'),
#  ('StreetName', 'ADA'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1320,'),
#  ('StreetName', 'NINTH'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1578,'),
#  ('StreetName', 'HOPKINS'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94707'),
#  ('AddressNumber', '1124,'),
#  ('StreetName', 'OXFORD'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94707'),
#  ('AddressNumber', '910,'),
#  ('StreetName', 'COLUSA'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '2,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94707'),
#  ('AddressNumber', '2106,'),
#  ('StreetName', 'CALIFORNIA'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1545,'),
#  ('StreetName', 'ADDISON'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1309,'),
#  ('StreetName', 'HOPKINS'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1231,'),
#  ('StreetName', 'FOURTH'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'A,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1230,'),
#  ('StreetName', 'KAINS'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94706'),
#  ('AddressNumber', '1846,'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '3,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2804,'),
#  ('StreetName', 'HILLEGASS'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '3,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2314,'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2741,'),
#  ('StreetName', 'GARBER'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '2,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2444,'),
#  ('StreetName', 'VIRGINIA'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'B,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2210,'),
#  ('StreetName', 'STUART'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2808,'),
#  ('StreetName', 'HILLEGASS'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', 'A1,'),
#  ('PlaceName', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2623,'),
#  ('StreetName', 'BENVENUE'),
#  ('StreetNamePostType', 'AVE,'),
#  ('PlaceName', 'A,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1921,'),
#  ('StreetName', 'HASTE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1521,'),
#  ('StreetName', 'HEARST'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1207,'),
#  ('StreetName', 'FRANCISCO'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1232,'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1718,'),
#  ('StreetName', 'CHANNING'),
#  ('StreetNamePostType', 'WAY,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2365,'),
#  ('StreetName', 'VIRGINIA'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '800,'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1-1,'),
#  ('PlaceName', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2601,'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '107,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2120,'),
#  ('StreetName', 'SIXTH'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '7,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2985,'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '51,'),
#  ('StreetName', 'OAKVALE'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2922,'),
#  ('StreetName', 'HILLEGASS'),
#  ('StreetNamePostType', 'AVE,'),
#  ('PlaceName', 'A,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2980,'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1434,'),
#  ('StreetName', 'BERKELEY'),
#  ('StreetNamePostType', 'WAY,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1336,'),
#  ('StreetName', 'BERKELEY'),
#  ('StreetNamePostType', 'WAY,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1209,'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2550,'),
#  ('StreetName', 'DANA'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', 'G1,'),
#  ('PlaceName', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2430,'),
#  ('StreetName', 'FIFTH'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'A,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1814,'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2326,'),
#  ('StreetName', 'BROWNING'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1515,'),
#  ('StreetName', 'HOPKINS'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '5,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94707'),
#  ('AddressNumber', '1404,'),
#  ('StreetName', 'HENRY'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '2,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2634,'),
#  ('StreetName', 'VIRGINIA'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '23,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2325,'),
#  ('StreetName', 'HOWE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2316,'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'B,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2602,'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2405,'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2600,'),
#  ('StreetName', 'ETNA'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '3,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2430,'),
#  ('StreetName', 'TENTH'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '3036,'),
#  ('StreetName', 'FULTON'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'A,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2636,'),
#  ('StreetName', 'REGENT'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '3109,'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE,'),
#  ('PlaceName', 'A,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '3045,'),
#  ('StreetName', 'DEAKIN'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'L,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1832,'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1629,'),
#  ('StreetName', 'EIGHTH'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2021,'),
#  ('StreetName', 'HEARST'),
#  ('StreetNamePostType', 'AVE,'),
#  ('PlaceName', 'B,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2220,'),
#  ('StreetName', 'SACRAMENTO'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '7,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1810,'),
#  ('StreetName', 'DWIGHT'),
#  ('StreetNamePostType', 'WAY,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2980,'),
#  ('StreetName', 'COLLEGE'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '9,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2550,'),
#  ('StreetName', 'DANA'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', 'G9,'),
#  ('PlaceName', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '930,'),
#  ('StreetName', 'CARLETON'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2723,'),
#  ('StreetName', 'ASHBY'),
#  ('StreetNamePostType', 'PL,'),
#  ('PlaceName', 'A,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1726,'),
#  ('StreetName', 'HEARST'),
#  ('StreetNamePostType', 'AVE,'),
#  ('PlaceName', 'B,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2314,'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2547,'),
#  ('StreetName', 'PIEDMONT'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '2,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1294,'),
#  ('StreetName', 'MONTEREY'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94707'),
#  ('AddressNumber', '2043,'),
#  ('StreetName', 'BERRYMAN'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2418,'),
#  ('StreetName', 'FIFTH'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'B,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2601,'),
#  ('StreetName', 'DANA'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'A,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2632,'),
#  ('StreetName', 'HILLEGASS'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1740,'),
#  ('StreetName', 'ADDISON'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'A,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1812,'),
#  ('StreetName', 'SIXTH'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1672,'),
#  ('StreetName', 'UNIVERSITY'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '2550,'),
#  ('StreetName', 'DANA'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', 'G6,'),
#  ('PlaceName', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2348,'),
#  ('StreetName', 'HILGARD'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2741,'),
#  ('StreetName', 'GARBER'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '6,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2016,'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'C,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2414,'),
#  ('StreetName', 'HILGARD'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2634,'),
#  ('StreetName', 'VIRGINIA'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '12,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1658,'),
#  ('StreetName', 'CALIFORNIA'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1785,'),
#  ('StreetName', 'OXFORD'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1767,'),
#  ('StreetName', 'EUCLID'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1521,'),
#  ('StreetName', 'M'),
#  ('StreetName', 'L'),
#  ('StreetName', 'KING'),
#  ('StreetName', 'JR'),
#  ('StreetNamePostType', 'WAY,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2501,'),
#  ('StreetName', 'DANA'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2425,'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2646,'),
#  ('StreetName', 'ASHBY'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2323,'),
#  ('StreetName', 'HOWE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '2,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '1822,'),
#  ('StreetName', 'BERKELEY'),
#  ('StreetNamePostType', 'WAY,'),
#  ('OccupancyIdentifier', '2,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94703'),
#  ('AddressNumber', '1211,'),
#  ('StreetName', 'DELAWARE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2512,'),
#  ('StreetName', 'NINTH'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2415,'),
#  ('StreetName', 'FIFTH'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2115,'),
#  ('StreetName', 'STUART'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2133,'),
#  ('StreetName', 'DERBY'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94705'),
#  ('AddressNumber', '2640,'),
#  ('StreetName', 'BENVENUE'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2626,'),
#  ('StreetName', 'BENVENUE'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2905,'),
#  ('StreetName', 'CHANNING'),
#  ('StreetNamePostType', 'WAY,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1300,'),
#  ('StreetName', 'ADDISON'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2029,'),
#  ('StreetName', 'CHANNING'),
#  ('StreetNamePostType', 'WAY,'),
#  ('OccupancyIdentifier', '2B,'),
#  ('PlaceName', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2220,'),
#  ('StreetName', 'SACRAMENTO'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '6,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '2201,'),
#  ('StreetName', 'VIRGINIA'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '6,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '1730,'),
#  ('StreetName', 'HIGHLAND'),
#  ('StreetNamePostType', 'PL,'),
#  ('OccupancyIdentifier', '1,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94709'),
#  ('AddressNumber', '2614,'),
#  ('StreetName', 'WARRING'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '3,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '2407,'),
#  ('StreetName', 'BLAKE'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94704'),
#  ('AddressNumber', '1012,'),
#  ('StreetName', 'GRAYSON'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'B,'),
#  ('StateName', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '1127,'),
#  ('StreetName', 'HEARST'),
#  ('StreetNamePostType', 'AVE,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94702'),
#  ('AddressNumber', '1729,'),
#  ('StreetName', 'SIXTH'),
#  ('StreetNamePostType', 'ST,'),
#  ('OccupancyIdentifier', '0,'),
#  ('OccupancyIdentifier', 'BERKELEY,'),
#  ('ZipCode', '94710'),
#  ('AddressNumber', '2619,'),
#  ('StreetName', 'ETNA'),
#  ('StreetNamePostType', 'ST,'),
#  ('PlaceName', 'A,'),
#  ...]

# %% [markdown]
# # Difficult Parsing: with 2 examples of psuedo U.S. address formats
# + Similar to real U.S. addresses with some unstructured data
#     + 1<sup>st</sup>: working with a .csv dump, simulating possible web-scraped data
#     + 2<sup>nd</sup>: Python `Faker` package `.address`

# %%
# Creating Fake Addresses: (ONLY USE if USING "FAKER" package)

def address_stuff(h):
    user_list=[]
    for i in range(0,h):
        user_list.append(fake_data.address())
#         user_list.append(fake_data.city())
#         user_list.append(fake_data.state_abbr())
#         user_list.append(fake_data.user_name())

    return user_list     #pay attn here if indented more it overrides data and prints 1

# %%
fake_data.address()
# Out:
# '21353 Nicole Rue Suite 706\nPort David, MO 39157'

# %%
# Creating CSV and exporting to my directory with 6001 entries:

with open('fake_address.csv','w',newline='') as csvfile:
    CSV_fake_=csv.writer(csvfile)
    
    for i in address_stuff(6001):
        CSV_fake_.writerow([i])

# as a side note: if you don't use ('with') then you have to close() the file at the end

# %% [markdown]
# # Ex.1) Parse Addresses [.csv dump] using (usaddress.parse())
# + 1<sup>st</sup>: create inputs(address_funcrion,size)
# + 2<sup>nd</sup>: parse addresses using [usaddress.tag()]
# + 3<sup>rd</sup>: convert OrdDict() --> list(tup())
# + 4<sup>th</sup>: take list(tup()) --> Dict() with list(values()) convert to df (account for *missing values*) [*this is important because: there are miss-matching rows*]

# %%
# Unparsed Raw addresses:

unparsed_data=pd.read_csv('fake_address.csv', header=None)

unparsed_df_tolist = unparsed_data.values.tolist()

h=[]
hh=[]

for i in unparsed_df_tolist:
    hh.extend(i) #using this to get rid of nested lists because parser can't read directly      

for j in hh:
    h.extend(usaddress.parse(j))


q=[(sub[1], sub[0]) for sub in h] # switching order to create (key:value) pairs
qq=Convert(q, dictionary)
uo=pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in qq.items()]))

# %%
uo.head()
# Out:
#   AddressNumber StreetName StreetNamePostType     PlaceName StateName ZipCode  \
# 0           774    Michael             Ways\n  Desireemouth        MO   92256
# 1           000       Ross          Circles\n      Clayland        IN   94270
# 2           789  Hernandez             Street      Anamouth        LA   65211
# 3           202       Adam               Park   Lake Martin        AK   46226
# 4         13819    Darrell            Falls\n           APO        AA   40334
#
#   OccupancyType OccupancyIdentifier SubaddressType SubaddressIdentifier  \
# 0         Suite               563\n            PSC                 8070
# 1         Suite               818\n            PSC                 5276
# 2          Apt.               598\n            PSC                 3552
# 3          Apt.               892\n            PSC                 6716
# 4         Suite               132\n            PSC                 2301
#
#   USPSBoxType USPSBoxID StreetNamePostDirectional         Recipient  \
# 0         Box    1131\n                     North     USNV Bishop\n
# 1         Box    7165\n                      West  USNV Singleton\n
# 2         Box    5871\n                     South    USS Anderson\n
# 3         Box    3849\n                      East      USNS James\n
# 4         Box    0854\n                     South       USS Lopez\n
#
#   LandmarkName StreetNamePreDirectional
# 0  USNS Hill\n                     West
# 1          USS                      NaN
# 2       Byrd\n                      NaN
# 3          NaN                      NaN
# 4          NaN                      NaN

# %% [markdown]
# # Ex. 2) Using Python Faker and parsing addresses: using (usaddress.tag())

# %%
''' def add_parse: using 'tag' is a more robust parser but does have limitations
                   with this method you are creating an OrderedDict(),
        
    def Convert: creating dictionary where you have (key:[values]), 
    
    list comprehension: inside the dataframe it is used directly, the purpose is to loop over (key:value) 
                        and account for NaN values. The dataset has miss-matched rows, 
                        because not all columns apply and throws an arrow.
                        
    __One thing to note__: the more values you create the more Nan values and obscure addresses you create and 
                       parsing becomes an issue. 
        '''

def add_parse(address_stuff,qty):
    g=address_stuff(qty)
    h=[]
    for i in g:
        h.append(usaddress.tag(i)) 
    pp=[]
    for i in range(len(h)):
        o=h[i]
    #     pp.append([o[0].items()])
    #     op.append(o[0].values())
        for k in o[0].items():
                pp.append(k)             
    return pp
#----------------------------------

pp=add_parse(address_stuff,600) # adding values such as 6000, throws an error! this is explained below
#-------------------------

dictionary = {} 
g=(Convert(pp, dictionary))

pd.DataFrame(dict([(k,pd.Series(v)) for k,v in g.items() ]))
# Out:
#     AddressNumber StreetName StreetNamePostType       PlaceName StateName  \
# 0           99867     Wilson           Forest\n    Barbaraburgh        NM
# 1           61391     Lauren            Curve\n      Stevenside        ID
# 2            6311    Richard               Ways  Shermanborough        KY
# 3             749   Figueroa           Turnpike      Port Derek        IN
# 4           70932      Baker              Place       Colemouth        GA
# ..            ...        ...                ...             ...       ...
# 595           NaN        NaN                NaN      Lopezville        TN
# 596           NaN        NaN                NaN     Francistown        HI
# 597           NaN        NaN                NaN      Samuelland        WI
# 598           NaN        NaN                NaN             FPO        AA
# 599           NaN        NaN                NaN             DPO        AE
#
#     ZipCode StreetNamePostDirectional OccupancyType OccupancyIdentifier  \
# 0     00684                     North         Suite               306\n
# 1     10310                     North          Apt.               515\n
# 2     78438                      East         Suite               103\n
# 3     63986                     North          Apt.               584\n
# 4     18586                     South          Apt.               935\n
# ..      ...                       ...           ...                 ...
# 595   33729                       NaN           NaN                 NaN
# 596   75706                       NaN           NaN                 NaN
# 597   63502                       NaN           NaN                 NaN
# 598   28555                       NaN           NaN                 NaN
# 599   85117                       NaN           NaN                 NaN
#
#     SubaddressType SubaddressIdentifier USPSBoxType USPSBoxID  \
# 0              PSC                 2990         Box    0045\n
# 1              PSC                 4606         Box    2190\n
# 2              PSC                 8017         Box    7624\n
# 3              PSC                 1624         Box    7140\n
# 4              PSC                 4325         Box    8062\n
# ..             ...                  ...         ...       ...
# 595            NaN                  NaN         NaN       NaN
# 596            NaN                  NaN         NaN       NaN
# 597            NaN                  NaN         NaN       NaN
# 598            NaN                  NaN         NaN       NaN
# 599            NaN                  NaN         NaN       NaN
#
#            Recipient LandmarkName
# 0      USS Morales\n  USNS West\n
# 1     USCGC Bender\n          NaN
# 2    USNS Martinez\n          NaN
# 3        USNS Pope\n          NaN
# 4       USS Palmer\n          NaN
# ..               ...          ...
# 595              NaN          NaN
# 596              NaN          NaN
# 597              NaN          NaN
# 598              NaN          NaN
# 599              NaN          NaN
#
# [600 rows x 15 columns]

# %%
# Dump file to csv (export)
y=pd.DataFrame(dict([(k,pd.Series(v)) for k,v in g.items() ]))
y.to_csv('ce.csv',index=False,header=False)

# %% [markdown]
# # This image allows you to see one of the problems with parsing:
# + This particular address and similar are not exactly [REAL U.S. ADDRESSES] which create problems for this package.
# + If you evaluate the data it

# %% [markdown]
# ![](address_parse_fail.jpg)

# %% [markdown]
# ![](address_parse_fail.png)

# %% [markdown]
# # This is the error code:
# + When I store larger datasets of fake addresses this occurs because it is a quesitonable address and the parser cannot parse

# %% [markdown]
# ![](error_code.png)

# %% [markdown]
# # Citations
#
#  https://www.geeksforgeeks.org/python-split-list-into-lists-by-particular-value/
#
# https://stackoverflow.com/questions/19736080/creating-dataframe-from-a-dictionary-where-entries-have-different-lengths
#
# https://www.geeksforgeeks.org/python-swap-tuple-elements-in-list-of-tuples/
#
# https://stackoverflow.com/questions/49638992/generating-test-data-how-to-generate-a-valid-address-for-a-given-us-zipcode
#
# https://stackoverflow.com/questions/9234560/find-all-csv-files-in-a-directory-using-python/38584736
